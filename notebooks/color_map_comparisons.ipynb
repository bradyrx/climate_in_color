# %% [markdown]
# # What makes a "good" colormap?
# Overview text.

# %%
import proplot as plot
plot.rc.small = 10
plot.rc.large = 12

# %% [markdown]
# # Perceptually uniform colorspaces

# %% [markdown]
# Text on perceptually uniform colorspaces, how they can be used to design "good" colormaps, the challenges posed by "impossible colors".

# %%
import proplot as plot
f = plot.show_colorspaces(saturation=50)
f = plot.show_colorspaces(luminance=50)
f = plot.show_colorspaces(hue=0)

# %% [markdown]
# # Bad colormaps

# %% [markdown]
# Mention many popular colormaps are used for historical reasons or for their simplicity when defined in RGB space, but they predate developments in data visualization and color theory. Even sort-of-nice-looking ones like "hot" have awkward ledges and thresholds in luminance space.

# %%
import bad_cmaps
cmaps = bad_cmaps.load_cmaps()

# %%
import proplot as plot
f = plot.show_cmaps(*cmaps, length=3, width=0.3)
# Out:
# /Users/ldavis/proplot/proplot/subplots.py:862: ProPlotWarning: Got negative top margin in smart tight layout.

# %%
import proplot as plot
f = plot.show_channels('jet', 'hsv')
f = plot.show_channels('hot', 'gnuplot', 'screenshot2')

# %% [markdown]
# # Good colormaps

# %% [markdown]
# Mention the different projects, difficulty of getting smooth gradations on all channels but most of these maps are smooth in at least two.

# %%
import re
import proplot as plot
cmaps = [cmap for cmap in plot.cmaps if not re.match('^.*[0-9]$', cmap)]
f = plot.show_cmaps(*cmaps, length=3, width=0.3)
# Out:
# /Users/ldavis/proplot/proplot/subplots.py:862: ProPlotWarning: Got negative top margin in smart tight layout.

# %%
import proplot as plot
f = plot.show_channels('ice','glacial','dusk', rgb=False)

# %%
import proplot as plot
f = plot.show_channels('BuRd','Balance','NegPos', rgb=False)
