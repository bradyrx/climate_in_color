# %%
import proplot as plot
from cmaps import cmaps
plot.rc.small = 12
plot.rc.large = 14

# %% [markdown]
# # Bad examples

# %%
f = plot.show_cmaps(cmaps, cbarlength=6, cbarwidth=0.3)

# %% [markdown]
# # Cmap breakdowns

# %%
for cmap in ('cmap1','cmap2','jet','hsv'):
    plot.breakdown_cmap(cmap, axwidth=2)
# Out:
# /Users/ldavis/proplot/proplot/wrappers.py:1776: ProPlotWarning: Warning: converting a masked element to nan.
# /Users/ldavis/miniconda3/lib/python3.7/site-packages/matplotlib/contour.py:1520: UserWarning: Warning: converting a masked element to nan.
#         self.zmax = float(z.max())
#
# /Users/ldavis/miniconda3/lib/python3.7/site-packages/matplotlib/contour.py:1521: UserWarning: Warning: converting a masked element to nan.
#         self.zmin = float(z.min())
